# %% [markdown]
# #

# %% [markdown]
# #Gas Sensor Array Drift Dataset Data Set

# %% [markdown]
# https://archive.ics.uci.edu/ml/datasets/gas+sensor+array+drift+dataset

# %% [markdown]
# #Load Dataset on google colab  notebook

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00224/Dataset.zip
# Out:
# --2019-06-02 10:02:41--  https://archive.ics.uci.edu/ml/machine-learning-databases/00224/Dataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9989262 (9.5M) [application/x-httpd-php]
# Saving to: ‘Dataset.zip’
#
# Dataset.zip         100%[===================>]   9.53M  23.7MB/s    in 0.4s
#
# 2019-06-02 10:02:41 (23.7 MB/s) - ‘Dataset.zip’ saved [9989262/9989262]

# %%
# !unzip Dataset.zip
# Out:
# Archive:  Dataset.zip
#    creating: Dataset/
#   inflating: Dataset/batch1.dat
#   inflating: Dataset/batch10.dat
#   inflating: Dataset/batch2.dat
#   inflating: Dataset/batch3.dat
#   inflating: Dataset/batch4.dat
#   inflating: Dataset/batch5.dat
#   inflating: Dataset/batch6.dat
#   inflating: Dataset/batch7.dat
#   inflating: Dataset/batch8.dat
#   inflating: Dataset/batch9.dat

# %% [markdown]
# #Import required library

# %%
import pandas as pd

# %% [markdown]
# #Explore batch1.dat file

# %%
batch_1 = pd.read_csv('Dataset/batch1.dat' , delimiter=' ' , header = None)
print(batch_1.shape)
batch_1.head()
# Out:
# (445, 129)
#    0               1           2    ...            126            127            128
# 0    1  1:15596.162100  2:1.868245  ...  126:-0.545079  127:-0.902241  128:-2.654529
# 1    1  1:26402.070400  2:2.532401  ...  126:-0.889333  127:-1.323505  128:-1.749225
# 2    1  1:42103.582000  2:3.454189  ...  126:-1.334558  127:-1.993659  128:-2.348370
# 3    1  1:42825.988300  2:3.451192  ...  126:-1.432205  127:-2.146158  128:-2.488957
# 4    1  1:58151.175700  2:4.194839  ...  126:-1.930107  127:-2.931265  128:-4.088756
#
# [5 rows x 129 columns]

# %% [markdown]
# ### Feature Engineering
# Extraxt useful and important inforamtion

# %%
batch_1[0].value_counts()
# Out:
# 2    98
# 1    90
# 3    83
# 6    74
# 5    70
# 4    30
# Name: 0, dtype: int64

# %%
h = list(batch_1[0].values)

batch_1.insert(0, "Gases",h, True) 
print(batch_1.shape)
batch_1.head()
# Out:
# (445, 130)
#    Gases  0               1  ...            126            127            128
# 0      1  1  1:15596.162100  ...  126:-0.545079  127:-0.902241  128:-2.654529
# 1      1  1  1:26402.070400  ...  126:-0.889333  127:-1.323505  128:-1.749225
# 2      1  1  1:42103.582000  ...  126:-1.334558  127:-1.993659  128:-2.348370
# 3      1  1  1:42825.988300  ...  126:-1.432205  127:-2.146158  128:-2.488957
# 4      1  1  1:58151.175700  ...  126:-1.930107  127:-2.931265  128:-4.088756
#
# [5 rows x 130 columns]

# %%
liss = []
for i in list(batch_1.columns):
    liss.append(str(i))
batch_1.columns = liss

# %%
#batch_1.info(include='all')
batch_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445 entries, 0 to 444
# Columns: 130 entries, Gases to 128
# dtypes: int64(2), object(128)
# memory usage: 452.0+ KB

# %%
batch_1.drop(['0'] , inplace=True , axis = 1)
print(batch_1.shape)
batch_1.head()
# Out:
# (445, 129)
#    Gases               1  ...            127            128
# 0      1  1:15596.162100  ...  127:-0.902241  128:-2.654529
# 1      1  1:26402.070400  ...  127:-1.323505  128:-1.749225
# 2      1  1:42103.582000  ...  127:-1.993659  128:-2.348370
# 3      1  1:42825.988300  ...  127:-2.146158  128:-2.488957
# 4      1  1:58151.175700  ...  127:-2.931265  128:-4.088756
#
# [5 rows x 129 columns]

# %%
batch_1['Gases'].value_counts()
# Out:
# 2    98
# 1    90
# 3    83
# 6    74
# 5    70
# 4    30
# Name: Gases, dtype: int64

# %%
list(batch_1['Gases'].values)[:5]
# Out:
# [1, 1, 1, 1, 1]

# %%
#1: Ethanol; 2: Ethylene; 3:Ammonia; 4: Acetaldehyde; 5: Acetone; 6: Toluene
d=[]
for i in list(batch_1['Gases'].values):
    if(i==1):
        d.append('Ethanol')
    elif(i==2):
        d.append('Ethylene')
    elif(i==3):
        d.append('Ammonia')
    elif(i==4):
        d.append('Acetaldehyde')
    elif(i==5):
        d.append('Acetone')
    else:
        d.append('Toluene')
        
set(d)
# Out:
# {'Acetaldehyde', 'Acetone', 'Ammonia', 'Ethanol', 'Ethylene', 'Toluene'}

# %%
batch_1.insert(0, 'Gas_Name',d, True) 
batch_1.drop(['Gases'] , inplace=True , axis = 1)
print(batch_1.shape)
batch_1.head()
# Out:
# (445, 129)
#   Gas_Name               1  ...            127            128
# 0  Ethanol  1:15596.162100  ...  127:-0.902241  128:-2.654529
# 1  Ethanol  1:26402.070400  ...  127:-1.323505  128:-1.749225
# 2  Ethanol  1:42103.582000  ...  127:-1.993659  128:-2.348370
# 3  Ethanol  1:42825.988300  ...  127:-2.146158  128:-2.488957
# 4  Ethanol  1:58151.175700  ...  127:-2.931265  128:-4.088756
#
# [5 rows x 129 columns]

# %%
batch_1['Gas_Name'].value_counts()
# Out:
# Ethylene        98
# Ethanol         90
# Ammonia         83
# Toluene         74
# Acetone         70
# Acetaldehyde    30
# Name: Gas_Name, dtype: int64

# %%
for j in list(batch_1.iloc[:,1:].columns):
    d=[]
    for i in list(batch_1[j].values):
        d.append(i.split(':')[1])
    batch_1[j]=d
    
    
print(batch_1.shape)
batch_1.head()
# Out:
# (445, 129)
#   Gas_Name             1         2  ...        126        127        128
# 0  Ethanol  15596.162100  1.868245  ...  -0.545079  -0.902241  -2.654529
# 1  Ethanol  26402.070400  2.532401  ...  -0.889333  -1.323505  -1.749225
# 2  Ethanol  42103.582000  3.454189  ...  -1.334558  -1.993659  -2.348370
# 3  Ethanol  42825.988300  3.451192  ...  -1.432205  -2.146158  -2.488957
# 4  Ethanol  58151.175700  4.194839  ...  -1.930107  -2.931265  -4.088756
#
# [5 rows x 129 columns]

# %% [markdown]
# ###Here , we have 128 features and 1 target variable

# %%
batch_1.set_index('Gas_Name',inplace=True)
print(batch_1.shape)
batch_1.head()
# Out:
# (445, 128)
#                      1         2          3  ...        126        127        128
# Gas_Name                                     ...
# Ethanol   15596.162100  1.868245   2.371604  ...  -0.545079  -0.902241  -2.654529
# Ethanol   26402.070400  2.532401   5.411209  ...  -0.889333  -1.323505  -1.749225
# Ethanol   42103.582000  3.454189   8.198175  ...  -1.334558  -1.993659  -2.348370
# Ethanol   42825.988300  3.451192  12.113940  ...  -1.432205  -2.146158  -2.488957
# Ethanol   58151.175700  4.194839  11.455096  ...  -1.930107  -2.931265  -4.088756
#
# [5 rows x 128 columns]

# %%
batch_1.reset_index(inplace=True)

# %%
df = batch_1
cols = df.columns.tolist()
#col = cols[-1:] + cols[:-1]
col = cols[1:] + cols[:1]
df = df[col]
df.to_csv('batch1.csv',index=False)

# %% [markdown]
# #Explore batch2.dat file

# %%
batch = pd.read_csv('Dataset/batch2.dat' , delimiter=' ' , header = None)
print(batch.shape)
batch.head()
# Out:
# (1244, 129)
#    0               1           2    ...            126            127            128
# 0    1  1:21749.563500  2:2.627488  ...  126:-0.760981  127:-1.218104  128:-1.605704
# 1    1  1:44240.502900  2:4.734847  ...  126:-1.277148  127:-1.949090  128:-2.349524
# 2    1  1:68772.517500  2:7.185827  ...  126:-1.734698  127:-2.711049  128:-4.501320
# 3    1  1:68632.830100  2:6.923039  ...  126:-2.054283  127:-3.145986  128:-4.389490
# 4    1  1:76428.971700  2:7.898322  ...  126:-2.435697  127:-3.776622  128:-4.187686
#
# [5 rows x 129 columns]

# %% [markdown]
# ### Feature Engineering
# Extraxt useful and important inforamtion

# %%
batch[0].value_counts()
# Out:
# 5    532
# 2    334
# 1    164
# 4    109
# 3    100
# 6      5
# Name: 0, dtype: int64

# %%
h = list(batch[0].values)

batch.insert(0, "Gases",h, True) 
print(batch.shape)
batch.head()
# Out:
# (1244, 130)
#    Gases  0               1  ...            126            127            128
# 0      1  1  1:21749.563500  ...  126:-0.760981  127:-1.218104  128:-1.605704
# 1      1  1  1:44240.502900  ...  126:-1.277148  127:-1.949090  128:-2.349524
# 2      1  1  1:68772.517500  ...  126:-1.734698  127:-2.711049  128:-4.501320
# 3      1  1  1:68632.830100  ...  126:-2.054283  127:-3.145986  128:-4.389490
# 4      1  1  1:76428.971700  ...  126:-2.435697  127:-3.776622  128:-4.187686
#
# [5 rows x 130 columns]

# %%
liss = []
for i in list(batch.columns):
    liss.append(str(i))
batch.columns = liss

# %%
#batch.info(include='all')
batch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1244 entries, 0 to 1243
# Columns: 130 entries, Gases to 128
# dtypes: int64(2), object(128)
# memory usage: 1.2+ MB

# %%
batch.drop(['0'] , inplace=True , axis = 1)

# %%
print(batch.shape)
batch.head()
# Out:
# (1244, 129)
#    Gases               1  ...            127            128
# 0      1  1:21749.563500  ...  127:-1.218104  128:-1.605704
# 1      1  1:44240.502900  ...  127:-1.949090  128:-2.349524
# 2      1  1:68772.517500  ...  127:-2.711049  128:-4.501320
# 3      1  1:68632.830100  ...  127:-3.145986  128:-4.389490
# 4      1  1:76428.971700  ...  127:-3.776622  128:-4.187686
#
# [5 rows x 129 columns]

# %%
batch['Gases'].value_counts()
# Out:
# 5    532
# 2    334
# 1    164
# 4    109
# 3    100
# 6      5
# Name: Gases, dtype: int64

# %%
list(batch['Gases'].values)[:5]
# Out:
# [1, 1, 1, 1, 1]

# %%
#  Ethanol, Ethylene, Ammonia, Acetaldehyde, Acetone, Toluene 
d=[]
for i in list(batch['Gases'].values):
    if(i==1):
        d.append('Ethanol')
    elif(i==2):
        d.append('Ethylene')
    elif(i==3):
        d.append('Ammonia')
    elif(i==4):
        d.append('Acetaldehyde')
    elif(i==5):
        d.append('Acetone')
    else:
        d.append('Toluene')
        
set(d)
# Out:
# {'Acetaldehyde', 'Acetone', 'Ammonia', 'Ethanol', 'Ethylene', 'Toluene'}

# %%
batch.insert(0, 'Gas_Name',d, True) 
batch.drop(['Gases'] , inplace=True , axis = 1)
print(batch.shape)
batch.head()
# Out:
# (1244, 129)
#   Gas_Name               1  ...            127            128
# 0  Ethanol  1:21749.563500  ...  127:-1.218104  128:-1.605704
# 1  Ethanol  1:44240.502900  ...  127:-1.949090  128:-2.349524
# 2  Ethanol  1:68772.517500  ...  127:-2.711049  128:-4.501320
# 3  Ethanol  1:68632.830100  ...  127:-3.145986  128:-4.389490
# 4  Ethanol  1:76428.971700  ...  127:-3.776622  128:-4.187686
#
# [5 rows x 129 columns]

# %%
batch['Gas_Name'].value_counts()
# Out:
# Acetone         532
# Ethylene        334
# Ethanol         164
# Acetaldehyde    109
# Ammonia         100
# Toluene           5
# Name: Gas_Name, dtype: int64

# %%
for j in list(batch.iloc[:,1:].columns):
    d=[]
    for i in list(batch[j].values):
        d.append(i.split(':')[1])
    batch[j]=d
    
    
print(batch.shape)
batch.head()
# Out:
# (1244, 129)
#   Gas_Name             1         2  ...        126        127        128
# 0  Ethanol  21749.563500  2.627488  ...  -0.760981  -1.218104  -1.605704
# 1  Ethanol  44240.502900  4.734847  ...  -1.277148  -1.949090  -2.349524
# 2  Ethanol  68772.517500  7.185827  ...  -1.734698  -2.711049  -4.501320
# 3  Ethanol  68632.830100  6.923039  ...  -2.054283  -3.145986  -4.389490
# 4  Ethanol  76428.971700  7.898322  ...  -2.435697  -3.776622  -4.187686
#
# [5 rows x 129 columns]

# %%
batch.set_index('Gas_Name',inplace=True)
print(batch.shape)
batch.head()
# Out:
# (1244, 128)
#                      1         2          3  ...        126        127        128
# Gas_Name                                     ...
# Ethanol   21749.563500  2.627488   3.507524  ...  -0.760981  -1.218104  -1.605704
# Ethanol   44240.502900  4.734847   8.465927  ...  -1.277148  -1.949090  -2.349524
# Ethanol   68772.517500  7.185827  12.939696  ...  -1.734698  -2.711049  -4.501320
# Ethanol   68632.830100  6.923039  20.863585  ...  -2.054283  -3.145986  -4.389490
# Ethanol   76428.971700  7.898322  19.106577  ...  -2.435697  -3.776622  -4.187686
#
# [5 rows x 128 columns]

# %%
batch.reset_index(inplace=True)
df = batch
cols = df.columns.tolist()
#col = cols[-1:] + cols[:-1]
col = cols[1:] + cols[:1]
df = df[col]
df.to_csv('batch2.csv',index=False)

# %% [markdown]
# #Explore ALL batch3.dat to batch10.dat files

# %%
l= ['batch10.dat','batch9.dat','batch8.dat' ,'batch7.dat' ,'batch6.dat' ,'batch5.dat' ,'batch4.dat'  ,'batch3.dat']           
for files in l[::-1]:
    file = 'Dataset/' + files
    batch = pd.read_csv(file, delimiter=' ' , header = None)
    h = list(batch[0].values)
    batch.insert(0, "Gases",h, True) 

    liss = []
    for i in list(batch.columns):
        liss.append(str(i))
    batch.columns = liss
    
    batch.drop(['0'] , inplace=True , axis = 1)
    #batch['Gases'] = batch['Gases'].astype('int64')

    d1=[]
    for i in list(batch['Gases'].values):
        if(i==1):
            d1.append('Ethanol')
        elif(i==2):
            d1.append('Ethylene')
        elif(i==3):
            d1.append('Ammonia')
        elif(i==4):
            d1.append('Acetaldehyde')
        elif(i==5):
            d1.append('Acetone')
        else:
            d1.append('Toluene')
            
            
    batch.insert(0, 'Gas_Name',d1, True ) 
    
    batch.drop(['Gases'] , inplace=True , axis = 1)
    
    for j in list(batch.iloc[:,1:].columns):
        d=[]
        for i in list(batch[j].values):
            d.append(i.split(':')[1])
        batch[j]=d
        
    batch.set_index('Gas_Name',inplace=True)
    batch.reset_index(inplace=True)
    
    df = batch
    cols = df.columns.tolist()
    #col = cols[-1:] + cols[:-1]
    col = cols[1:] + cols[:1]
    df = df[col]
    df.to_csv(file.split('.')[0]+'.csv',index=False)

# %% [markdown]
# #Again Explore files one by one before appending

# %%
#To upload the files from the local system to google colab notebook
from google.colab import files
files.upload()

# %%
batch = pd.read_csv('batch1.csv')
print(batch.shape)
batch.head()
# Out:
# (445, 129)
#             1         2          3  ...       127       128  Gas_Name
# 0  15596.1621  1.868245   2.371604  ... -0.902241 -2.654529   Ethanol
# 1  26402.0704  2.532401   5.411209  ... -1.323505 -1.749225   Ethanol
# 2  42103.5820  3.454189   8.198175  ... -1.993659 -2.348370   Ethanol
# 3  42825.9883  3.451192  12.113940  ... -2.146158 -2.488957   Ethanol
# 4  58151.1757  4.194839  11.455096  ... -2.931265 -4.088756   Ethanol
#
# [5 rows x 129 columns]

# %%
batch['Gas_Name'].value_counts()
# Out:
# Ethylene        98
# Ethanol         90
# Ammonia         83
# Toluene         74
# Acetone         70
# Acetaldehyde    30
# Name: Gas_Name, dtype: int64

# %%
batch = pd.read_csv('batch2.csv')
print(batch.shape)
batch.head()
# Out:
# (1244, 129)
#             1         2          3  ...       127       128  Gas_Name
# 0  21749.5635  2.627488   3.507524  ... -1.218104 -1.605704   Ethanol
# 1  44240.5029  4.734847   8.465927  ... -1.949090 -2.349524   Ethanol
# 2  68772.5175  7.185827  12.939696  ... -2.711049 -4.501320   Ethanol
# 3  68632.8301  6.923039  20.863585  ... -3.145986 -4.389490   Ethanol
# 4  76428.9717  7.898322  19.106577  ... -3.776622 -4.187686   Ethanol
#
# [5 rows x 129 columns]

# %%
batch['Gas_Name'].value_counts()
# Out:
# Acetone         532
# Ethylene        334
# Ethanol         164
# Acetaldehyde    109
# Ammonia         100
# Toluene           5
# Name: Gas_Name, dtype: int64

# %%
batch = pd.read_csv('batch3.csv')
print(batch.shape)
batch.head()
# Out:
# (1586, 129)
#              1          2          3  ...        127        128  Gas_Name
# 0  142327.2957  35.814268  41.424486  ... -22.660650 -34.423102   Ethanol
# 1  143843.4629  44.693740  41.479671  ... -22.844437 -32.360008   Ethanol
# 2  138898.2343  38.061920  40.788719  ... -24.184186 -36.519754   Ethanol
# 3  131015.3828  39.382857  39.604255  ... -23.761675 -33.565944   Ethanol
# 4  132226.0671  34.139144  40.013897  ... -23.535263 -33.884694   Ethanol
#
# [5 rows x 129 columns]

# %%
batch['Gas_Name'].value_counts()
# Out:
# Ethylene        490
# Ethanol         365
# Acetone         275
# Acetaldehyde    240
# Ammonia         216
# Name: Gas_Name, dtype: int64

# %%
batch = pd.read_csv('batch4.csv')
print(batch.shape)
batch.head()
# Out:
# (161, 129)
#             1          2          3  ...        127        128  Gas_Name
# 0  79669.6210  57.102431  12.165471  ... -11.838076 -16.338610   Ethanol
# 1  78168.3037  41.166591  22.355165  ... -12.526578 -17.380774   Ethanol
# 2  78706.0460  41.288937  22.071437  ... -12.988813 -18.296826   Ethanol
# 3  78223.6473  42.084330  22.206579  ... -13.216110 -18.937609   Ethanol
# 4  78369.6472  41.883374  21.997497  ... -13.210008 -19.442135   Ethanol
#
# [5 rows x 129 columns]

# %%
batch['Gas_Name'].value_counts()
# Out:
# Ethanol         64
# Ethylene        43
# Acetaldehyde    30
# Acetone         12
# Ammonia         12
# Name: Gas_Name, dtype: int64

# %%
batch = pd.read_csv('batch5.csv')
print(batch.shape)
batch.head()
# Out:
# (197, 129)
#             1          2          3  ...        127        128  Gas_Name
# 0  78149.2265  14.931934  24.973869  ... -10.440939 -16.699372   Ethanol
# 1  77671.4096  19.516905  23.689007  ... -10.503444 -15.642171   Ethanol
# 2  76876.4980  18.515339  23.432006  ... -10.829415 -16.879491   Ethanol
# 3  76038.1509  17.993585  23.119231  ... -10.694796 -17.192846   Ethanol
# 4  74730.7637  17.534548  22.710518  ... -10.888158 -17.432184   Ethanol
#
# [5 rows x 129 columns]

# %%
batch['Gas_Name'].value_counts()
# Out:
# Acetone         63
# Acetaldehyde    46
# Ethylene        40
# Ethanol         28
# Ammonia         20
# Name: Gas_Name, dtype: int64

# %%
batch = pd.read_csv('batch6.csv')
print(batch.shape)
batch.head()
# Out:
# (2300, 129)
#             1         2         3  ...        127        128  Gas_Name
# 0  12714.6099  6.829581  2.552121  ... -19.031142 -36.552787  Ethylene
# 1  13484.3284  5.950336  3.028627  ... -17.072300 -34.363498  Ethylene
# 2  13041.8615  6.493913  2.971226  ... -17.424659 -34.619063  Ethylene
# 3  11601.2852  7.142976  2.503956  ... -17.407311 -35.316034  Ethylene
# 4  12225.6875  7.114277  2.585368  ... -18.646922 -35.613089  Ethylene
#
# [5 rows x 129 columns]

# %%
batch['Gas_Name'].value_counts()
# Out:
# Acetone         606
# Ethylene        574
# Ethanol         514
# Toluene         467
# Ammonia         110
# Acetaldehyde     29
# Name: Gas_Name, dtype: int64

# %%
batch = pd.read_csv('batch7.csv')
print(batch.shape)
batch.head()
# Out:
# (3613, 129)
#              1          2          3  ...        127        128  Gas_Name
# 0   73159.5410   8.054461  23.419016  ...  -9.830712 -18.115832   Ethanol
# 1   17214.4062   3.066851   8.694492  ...  -2.282508  -5.792101   Ethanol
# 2   72499.9805  11.760671  19.784823  ... -11.199621 -23.712482  Ethylene
# 3    5193.0732   1.501464   2.192588  ...  -1.014355  -4.309950  Ethylene
# 4  110085.7266  12.956479  32.468904  ... -18.636615 -29.208257   Ethanol
#
# [5 rows x 129 columns]

# %%
batch['Gas_Name'].value_counts()
# Out:
# Acetaldehyde    744
# Ethylene        662
# Ethanol         649
# Acetone         630
# Toluene         568
# Ammonia         360
# Name: Gas_Name, dtype: int64

# %%
batch = pd.read_csv('batch8.csv')
print(batch.shape)
batch.head()
# Out:
# (294, 129)
#            1         2         3  ...       127       128      Gas_Name
# 0   191.6784  1.097676  0.085713  ... -4.585015 -8.863957  Acetaldehyde
# 1  1026.7711  1.778150  0.217603  ... -2.131961 -5.697300       Acetone
# 2   311.8748  1.195577  0.105731  ... -4.620737 -9.125395  Acetaldehyde
# 3   987.0169  1.843827  0.218607  ... -2.154179 -5.951694       Acetone
# 4   152.4063  1.100063  0.076945  ... -4.708727 -9.735142  Acetaldehyde
#
# [5 rows x 129 columns]

# %%
batch['Gas_Name'].value_counts()
# Out:
# Acetone         143
# Ammonia          40
# Acetaldehyde     33
# Ethylene         30
# Ethanol          30
# Toluene          18
# Name: Gas_Name, dtype: int64

# %%
batch = pd.read_csv('batch9.csv')
print(batch.shape)
batch.head()
# Out:
# (470, 129)
#             1         2         3  ...       127        128      Gas_Name
# 0  11977.0371  2.946364  2.490357  ... -2.142489  -6.199217       Acetone
# 1  21234.2896  4.223873  4.758852  ... -6.365457 -12.539143  Acetaldehyde
# 2  13190.5258  3.139281  2.743704  ... -2.201871  -6.398889       Acetone
# 3  15803.7851  3.500589  3.375378  ... -6.422811 -12.380150  Acetaldehyde
# 4  16342.6787  3.497127  3.393961  ... -2.163901  -6.076439       Acetone
#
# [5 rows x 129 columns]

# %%
batch['Gas_Name'].value_counts()
# Out:
# Toluene         101
# Ammonia         100
# Acetone          78
# Acetaldehyde     75
# Ethanol          61
# Ethylene         55
# Name: Gas_Name, dtype: int64

# %%
batch = pd.read_csv('batch10.csv')
print(batch.shape)
batch.head()
# Out:
# (3600, 129)
#             1          2          3  ...       127        128      Gas_Name
# 0  12285.6582   4.076635   4.842317  ... -0.661556  -3.521663  Acetaldehyde
# 1    -35.6889   0.993944   0.166099  ... -0.534087  -4.635975       Ammonia
# 2  63927.2217  14.956941  19.971376  ... -6.731473 -19.326895  Acetaldehyde
# 3   2992.9019   1.380553   0.808910  ... -2.701235  -6.472439       Ammonia
# 4  57524.7812  11.912566  14.631496  ... -4.312744  -8.510591  Acetaldehyde
#
# [5 rows x 129 columns]

# %%
batch['Gas_Name'].value_counts()
# Out:
# Ammonia         600
# Acetaldehyde    600
# Ethylene        600
# Ethanol         600
# Toluene         600
# Acetone         600
# Name: Gas_Name, dtype: int64

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# #Append all the batch files

# %%
import pandas as pd
import glob
# !unzip Gas_Array_drift.zip
# Out:
# Archive:  Gas_Array_drift.zip
# replace batch9.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: batch9.csv
#   inflating: batch10.csv
#   inflating: batch1.csv
#   inflating: batch2.csv
#   inflating: batch3.csv
#   inflating: batch4.csv
#   inflating: batch5.csv
#   inflating: batch6.csv
#   inflating: batch7.csv
#   inflating: batch8.csv

# %%
path = r'/content/' # use your path

all_files = glob.glob(path + "/batch*.csv")
all_files
# Out:
# ['/content/batch9.csv',
#  '/content/batch5.csv',
#  '/content/batch4.csv',
#  '/content/batch1.csv',
#  '/content/batch7.csv',
#  '/content/batch8.csv',
#  '/content/batch2.csv',
#  '/content/batch10.csv',
#  '/content/batch6.csv',
#  '/content/batch3.csv']

# %%
li = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None)
    li.append(df)

final = pd.concat(li, axis=0, ignore_index=True)
final.to_csv('Batch.csv' , index= False)

batch = pd.read_csv('Batch.csv')
print(batch.shape)
batch[465:475]
# Out:
# (13910, 129)
#               1          2          3  ...        127        128  Gas_Name
# 465  13384.8262   2.820931   4.007378  ...  -2.457614  -6.226359   Toluene
# 466  13382.9619   2.825174   4.010915  ...  -2.493870  -6.859804   Toluene
# 467  13336.8725   2.822288   3.980818  ...  -2.504918  -6.263872   Toluene
# 468  13351.1318   2.824358   3.987819  ...  -2.438701  -6.044784   Toluene
# 469  13314.9336   2.816502   3.982182  ...  -2.463957  -5.726544   Toluene
# 470  78149.2265  14.931934  24.973869  ... -10.440939 -16.699372   Ethanol
# 471  77671.4096  19.516905  23.689007  ... -10.503444 -15.642171   Ethanol
# 472  76876.4980  18.515339  23.432006  ... -10.829415 -16.879491   Ethanol
# 473  76038.1509  17.993585  23.119231  ... -10.694796 -17.192846   Ethanol
# 474  74730.7637  17.534548  22.710518  ... -10.888158 -17.432184   Ethanol
#
# [10 rows x 129 columns]

# %%
batch['Gas_Name'].value_counts()
# Out:
# Acetone         3009
# Ethylene        2926
# Ethanol         2565
# Acetaldehyde    1936
# Toluene         1833
# Ammonia         1641
# Name: Gas_Name, dtype: int64

# %%
import matplotlib.pyplot as plt
import matplotlib
color = []
for name, hex in matplotlib.colors.cnames.items():
    #print(name, hex)
    color.append(name)

# Data to plot
plt.figure(figsize=[10,10])
label = (batch['Gas_Name'].value_counts().index)
count = (batch['Gas_Name'].value_counts().values)
colors = color[:6]
explode = (0.1, 0, 0, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(count, explode=explode, labels=label, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')

plt.show()

# %%
X = batch.iloc[:,:-1]   #Predictor 
y = batch.iloc[:,-1]   #Target Variable

print(X.shape)
print(y.shape)
# Out:
# (13910, 128)
# (13910,)

# %% [markdown]
# #Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
y = le.fit_transform(y)

# %%
set(y)
# Out:
# {0, 1, 2, 3, 4, 5}

# %%
X.head()
# Out:
#             1         2         3  ...       126       127        128
# 0  11977.0371  2.946364  2.490357  ... -1.387367 -2.142489  -6.199217
# 1  21234.2896  4.223873  4.758852  ... -4.112915 -6.365457 -12.539143
# 2  13190.5258  3.139281  2.743704  ... -1.459713 -2.201871  -6.398889
# 3  15803.7851  3.500589  3.375378  ... -4.010406 -6.422811 -12.380150
# 4  16342.6787  3.497127  3.393961  ... -1.451056 -2.163901  -6.076439
#
# [5 rows x 128 columns]

# %%
X.tail()
# Out:
#               1         2         3  ...       126       127        128
# 13905 -124.0596  0.974146  0.000169  ... -0.760267 -6.156265 -51.260295
# 13906  -53.6573  0.981065  0.002778  ... -0.712452 -5.667068 -48.430340
# 13907  -52.0076  0.980492  0.002451  ... -0.684826 -5.485327 -46.395341
# 13908  -57.6011  0.978761  0.000100  ... -0.663170 -5.291654 -43.661628
# 13909  -50.1287  0.981138  0.003742  ... -0.655771 -5.122259 -44.636621
#
# [5 rows x 128 columns]

# %% [markdown]
# #Normalization of predictors

# %%
import numpy as np
from sklearn.preprocessing import normalize

# %%
X1 = np.array(X)

# %%
print(X1.shape)
X1
# Out:
# (13910, 128)
# array([[ 1.19770371e+04,  2.94636400e+00,  2.49035700e+00, ...,
#         -1.38736700e+00, -2.14248900e+00, -6.19921700e+00],
#        [ 2.12342896e+04,  4.22387300e+00,  4.75885200e+00, ...,
#         -4.11291500e+00, -6.36545700e+00, -1.25391430e+01],
#        [ 1.31905258e+04,  3.13928100e+00,  2.74370400e+00, ...,
#         -1.45971300e+00, -2.20187100e+00, -6.39888900e+00],
#        ...,
#        [-5.20076000e+01,  9.80492000e-01,  2.45100000e-03, ...,
#         -6.84826000e-01, -5.48532700e+00, -4.63953410e+01],
#        [-5.76011000e+01,  9.78761000e-01,  1.00000000e-04, ...,
#         -6.63170000e-01, -5.29165400e+00, -4.36616280e+01],
#        [-5.01287000e+01,  9.81138000e-01,  3.74200000e-03, ...,
#         -6.55771000e-01, -5.12225900e+00, -4.46366210e+01]])

# %%
X2 = normalize(X1[:,:], axis=1)
print(X2.shape)
X2
# Out:
# (13910, 128)
# array([[ 3.88229590e-01,  9.55048964e-05,  8.07236605e-05, ...,
#         -4.49707985e-05, -6.94476955e-05, -2.00944478e-04],
#        [ 2.94943314e-01,  5.86694033e-05,  6.61002372e-05, ...,
#         -5.71282017e-05, -8.84159073e-05, -1.74168124e-04],
#        [ 2.83799626e-01,  6.75429310e-05,  5.90319280e-05, ...,
#         -3.14063298e-05, -4.73741665e-05, -1.37674747e-04],
#        ...,
#        [-2.62037076e-01,  4.94014829e-03,  1.23492119e-05, ...,
#         -3.45045344e-03, -2.76374808e-02, -2.33760056e-01],
#        [-3.01631363e-01,  5.12533640e-03,  5.23655560e-07, ...,
#         -3.47272658e-03, -2.77100404e-02, -2.28636543e-01],
#        [-2.39789894e-01,  4.69325909e-03,  1.78998016e-05, ...,
#         -3.13687087e-03, -2.45022501e-02, -2.13518616e-01]])

# %%
X3 = pd.DataFrame(X2)
print(X3.shape)
X3.head()
# Out:
# (13910, 128)
#         0         1         2    ...       125       126       127
# 0  0.388230  0.000096  0.000081  ... -0.000045 -0.000069 -0.000201
# 1  0.294943  0.000059  0.000066  ... -0.000057 -0.000088 -0.000174
# 2  0.283800  0.000068  0.000059  ... -0.000031 -0.000047 -0.000138
# 3  0.231238  0.000051  0.000049  ... -0.000059 -0.000094 -0.000181
# 4  0.303759  0.000065  0.000063  ... -0.000027 -0.000040 -0.000113
#
# [5 rows x 128 columns]

# %% [markdown]
# #Now we have two types of data
#  1. Normalize -----> X2, X3
#  2. Without Normalization -----> X  ,X1
#
#
#  And the target data  ------> y

# %% [markdown]
# # 1. Split the data into train and test using X2 dataset

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
y.shape
# Out:
# (13910,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X2, y, test_size=0.33, random_state=42)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (9319, 128)
# (9319,)
# (4591, 128)
# (4591,)

# %% [markdown]
# #Apply Machine learning Algorithms (classification )

# %%
#XGBOOST Algorithm
import xgboost as xgb
from xgboost.sklearn import XGBClassifier

xgb_model = XGBClassifier(silent=False, 
                      scale_pos_weight=1,
                      learning_rate=0.01,  
                      colsample_bytree = 0.4,
                      subsample = 0.8,
                      objective='binary:logistic', 
                      n_estimators=1000, 
                      reg_alpha = 0.3,
                      max_depth=4, 
                      gamma=10)
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.4, gamma=10,
#               learning_rate=0.01, max_delta_step=0, max_depth=4,
#               min_child_weight=1, missing=None, n_estimators=1000, n_jobs=1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0.3, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=False, subsample=0.8, verbosity=1)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_squared_error

# %%
# Predicting the Test set results
y_pred = xgb_model.predict(X_test)

print("Train Accuracy :: ", accuracy_score(y_test, y_pred)*100 ,'%' )
    

# Making the Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
pd.DataFrame(cm)
# Out:
# Train Accuracy ::  98.47527771727293 %
#      0    1    2    3    4    5
# 0  616    2    0    4    0    0
# 1    6  989    1    2    3    3
# 2    0    5  528    0    3    0
# 3    4    2    0  859    8    1
# 4    3    4    1    0  947    0
# 5   16    1    1    0    0  582

# %%
#RandomFroest Algorithm
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
# Predicting the Test set results
y_pred = rf_model.predict(X_test)

print("Train Accuracy :: ", accuracy_score(y_test, y_pred)*100 ,'%' )
    

# Making the Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
pd.DataFrame(cm)
# Out:
# Train Accuracy ::  99.36832934001308 %
#      0    1    2    3    4    5
# 0  622    0    0    0    0    0
# 1    1  998    2    0    1    2
# 2    0    2  532    0    2    0
# 3    1    0    1  865    6    1
# 4    1    3    2    0  949    0
# 5    4    0    0    0    0  596

# %%
pd.crosstab(y_test, y_pred)
# Out:
# col_0    0    1    2    3    4    5
# row_0
# 0      622    0    0    0    0    0
# 1        1  998    2    0    1    2
# 2        0    2  532    0    2    0
# 3        1    0    1  865    6    1
# 4        1    3    2    0  949    0
# 5        4    0    0    0    0  596

# %%
#APPLY logistic Regression
from sklearn.linear_model import LogisticRegression
lg_model = LogisticRegression()
lg_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Predicting the Test set results
y_pred = lg_model.predict(X_test)

print("Train Accuracy :: ", accuracy_score(y_test, y_pred)*100 ,'%' )
    

# Making the Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
pd.DataFrame(cm)
# Out:
# Train Accuracy ::  87.38836854715748 %
#      0    1    2    3    4    5
# 0  254   45    0  312    8    3
# 1    1  990    3    6    1    3
# 2    1    5  517    0   13    0
# 3   55   12    0  773    5   29
# 4    3   19    0    0  932    1
# 5    1   43    0    4    6  546

# %% [markdown]
# ### We have applied on Normalize dataset xgboost (98.47%)  , RandomForest(99.36%) , LogisticRgression (87.38%)

# %% [markdown]
# # 2. Split the data into train and test using X1 dataset

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X1 , y, test_size=0.33, random_state=42)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (9319, 128)
# (9319,)
# (4591, 128)
# (4591,)

# %% [markdown]
# #Apply Machine learning Algorithms (classification )

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
#XGBOOST Algorithm
import xgboost as xgb
from xgboost.sklearn import XGBClassifier

xgb_model = XGBClassifier(silent=False, 
                      scale_pos_weight=1,
                      learning_rate=0.01,  
                      colsample_bytree = 0.4,
                      subsample = 0.8,
                      objective='binary:logistic', 
                      n_estimators=1000, 
                      reg_alpha = 0.3,
                      max_depth=4, 
                      gamma=10)
xgb_model.fit(X_train, y_train)

# Predicting the Test set results
y_pred = xgb_model.predict(X_test)

print("Train Accuracy :: ", accuracy_score(y_test, y_pred)*100 ,'%' )
    

# Making the Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
pd.DataFrame(cm)
# Out:
# Train Accuracy ::  98.34458723589631 %
#      0    1    2    3    4    5
# 0  607    8    0    5    0    2
# 1    5  987    3    2    3    4
# 2    1    5  527    0    3    0
# 3    5    0    0  856   13    0
# 4    0    7    0    2  946    0
# 5    6    2    0    0    0  592

# %%
#RandomFroest Algorithm
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)

# Predicting the Test set results
y_pred = rf_model.predict(X_test)

print("Train Accuracy :: ", accuracy_score(y_test, y_pred)*100 ,'%' )
    

# Making the Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
pd.DataFrame(cm)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Train Accuracy ::  99.17229361794816 %
#      0    1    2    3    4    5
# 0  616    4    0    2    0    0
# 1    2  997    3    0    1    1
# 2    1    3  531    0    1    0
# 3    0    2    0  869    3    0
# 4    2    5    0    2  945    1
# 5    5    0    0    0    0  595

# %%
#APPLY logistic Regression
from sklearn.linear_model import LogisticRegression
lg_model = LogisticRegression()
lg_model.fit(X_train, y_train)
# Predicting the Test set results
y_pred = lg_model.predict(X_test)

print("Train Accuracy :: ", accuracy_score(y_test, y_pred)*100 ,'%' )
    

# Making the Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
pd.DataFrame(cm)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Train Accuracy ::  97.7564800697016 %
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
#      0    1    2    3    4    5
# 0  581   10    0   24    4    3
# 1   10  984    4    4    1    1
# 2    0    5  515   11    5    0
# 3    2    0    0  867    5    0
# 4    0    4    0    1  950    0
# 5    7    0    0    2    0  591

# %% [markdown]
# ### We have applied on Non-Normalize dataset -->xgboost (98.34%)  , RandomForest(99.17%) , LogisticRgression (97.75%)

# %% [markdown]
# #END

# %% [markdown]
# ---
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---
