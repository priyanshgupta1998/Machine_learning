# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshgupta1998/Machine_learning/blob/master/Gas_Sensor_Array_Drift_Dataset_at_Different_Concentrations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #

# %% [markdown]
# #Gas Sensor Array Drift Dataset at Different Concentrations

# %% [markdown]
# https://archive.ics.uci.edu/ml/datasets/Gas+Sensor+Array+Drift+Dataset+at+Different+Concentrations
#
# https://www.kaggle.com/jihyeseo/regression-no-missing-val-data-delim-whitespace

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00270/driftdataset.zip
# Out:
# --2019-05-31 21:30:39--  https://archive.ics.uci.edu/ml/machine-learning-databases/00270/driftdataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10118308 (9.6M) [application/x-httpd-php]
# Saving to: ‘driftdataset.zip’
#
# driftdataset.zip    100%[===================>]   9.65M  25.1MB/s    in 0.4s
#
# 2019-05-31 21:30:40 (25.1 MB/s) - ‘driftdataset.zip’ saved [10118308/10118308]

# %%
# !unzip driftdataset.zip
# Out:
# Archive:  driftdataset.zip
#   inflating: batch10.dat
#   inflating: batch9.dat
#   inflating: batch8.dat
#   inflating: batch7.dat
#   inflating: batch6.dat
#   inflating: batch5.dat
#   inflating: batch4.dat
#   inflating: batch3.dat
#   inflating: batch2.dat
#   inflating: batch1.dat

# %%
import pandas as pd

# %% [markdown]
# #Explore batch1.dat file

# %%
batch_1 = pd.read_csv('batch1.dat' , delimiter=' ' , header = None)
print(batch_1.shape)
batch_1.head()
# Out:
# (445, 130)
#            0               1           2    ...            127            128 129
# 0  1;10.000000  1:15596.162100  2:1.868245  ...  127:-0.902241  128:-2.654529 NaN
# 1  1;20.000000  1:26402.070400  2:2.532401  ...  127:-1.323505  128:-1.749225 NaN
# 2  1;30.000000  1:42103.582000  2:3.454189  ...  127:-1.993659  128:-2.348370 NaN
# 3  1;40.000000  1:42825.988300  2:3.451192  ...  127:-2.146158  128:-2.488957 NaN
# 4  1;50.000000  1:58151.175700  2:4.194839  ...  127:-2.931265  128:-4.088756 NaN
#
# [5 rows x 130 columns]

# %%
k  = batch_1
d=[]
for i in list(k[0].values):
    d.append(i.split(';')[0])
set(d)
# Out:
# {'1', '2', '3', '4', '5', '6'}

# %%
d=[]
h=[]
for i in list(batch_1[0].values):
    d.append(i.split(';')[1])
    h.append(i.split(';')[0])
batch_1[0]=d
batch_1.insert(0, "Gases",h, True) 
print(batch_1.shape)
batch_1.head()
# Out:
# (445, 131)
#   Gases          0               1  ...            127            128 129
# 0     1  10.000000  1:15596.162100  ...  127:-0.902241  128:-2.654529 NaN
# 1     1  20.000000  1:26402.070400  ...  127:-1.323505  128:-1.749225 NaN
# 2     1  30.000000  1:42103.582000  ...  127:-1.993659  128:-2.348370 NaN
# 3     1  40.000000  1:42825.988300  ...  127:-2.146158  128:-2.488957 NaN
# 4     1  50.000000  1:58151.175700  ...  127:-2.931265  128:-4.088756 NaN
#
# [5 rows x 131 columns]

# %%
liss = []
for i in list(batch_1.columns):
    liss.append(str(i))
batch_1.columns = liss

# %%
#batch_1.info(include='all')
batch_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445 entries, 0 to 444
# Columns: 131 entries, Gases to 129
# dtypes: float64(1), object(130)
# memory usage: 455.5+ KB

# %%
batch_1['129'].value_counts()
# Out:
# Series([], Name: 129, dtype: int64)

# %%
batch_1.drop(['129'] , inplace=True , axis = 1)
print(batch_1.shape)
batch_1.head()
# Out:
# (445, 130)
#   Gases          0               1  ...            126            127            128
# 0     1  10.000000  1:15596.162100  ...  126:-0.545079  127:-0.902241  128:-2.654529
# 1     1  20.000000  1:26402.070400  ...  126:-0.889333  127:-1.323505  128:-1.749225
# 2     1  30.000000  1:42103.582000  ...  126:-1.334558  127:-1.993659  128:-2.348370
# 3     1  40.000000  1:42825.988300  ...  126:-1.432205  127:-2.146158  128:-2.488957
# 4     1  50.000000  1:58151.175700  ...  126:-1.930107  127:-2.931265  128:-4.088756
#
# [5 rows x 130 columns]

# %%
batch_1['Gases'].value_counts()
# Out:
# 2    98
# 1    90
# 3    83
# 6    74
# 5    70
# 4    30
# Name: Gases, dtype: int64

# %%
print(batch_1[batch_1['Gases']].shape)
batch_1[batch_1['Gases']].head()
# Out:
# (445, 445)
#                 1               1  ...             6             6
# 0  1:15596.162100  1:15596.162100  ...   6:-2.739388   6:-2.739388
# 1  1:26402.070400  1:26402.070400  ...   6:-4.722217   6:-4.722217
# 2  1:42103.582000  1:42103.582000  ...   6:-7.668313   6:-7.668313
# 3  1:42825.988300  1:42825.988300  ...   6:-7.849409   6:-7.849409
# 4  1:58151.175700  1:58151.175700  ...  6:-11.083364  6:-11.083364
#
# [5 rows x 445 columns]

# %%
list(batch_1['Gases'].values)[:5]
# Out:
# ['1', '1', '1', '1', '1']

# %%
batch_1['Gases'] = batch_1['Gases'].astype('int64')


#pd.DataFrame(batch_1.iloc[:,0]).info()
pd.DataFrame(batch_1['Gases']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445 entries, 0 to 444
# Data columns (total 1 columns):
# Gases    445 non-null int64
# dtypes: int64(1)
# memory usage: 3.6 KB

# %%
#  Ethanol, Ethylene, Ammonia, Acetaldehyde, Acetone, Toluene 
d=[]
for i in list(batch_1['Gases'].values):
    if(i==1):
        d.append('Ethanol')
    elif(i==2):
        d.append('Ethylene')
    elif(i==3):
        d.append('Ammonia')
    elif(i==4):
        d.append('Acetaldehyde')
    elif(i==5):
        d.append('Acetone')
    else:
        d.append('Toluene')
        
set(d)
# Out:
# {'Acetaldehyde', 'Acetone', 'Ammonia', 'Ethanol', 'Ethylene', 'Toluene'}

# %%
batch_1.insert(0, 'Gas_Name',d, True) 
batch_1.drop(['Gases'] , inplace=True , axis = 1)
print(batch_1.shape)
batch_1.head()
# Out:
# (445, 130)
#   Gas_Name          0  ...            127            128
# 0  Ethanol  10.000000  ...  127:-0.902241  128:-2.654529
# 1  Ethanol  20.000000  ...  127:-1.323505  128:-1.749225
# 2  Ethanol  30.000000  ...  127:-1.993659  128:-2.348370
# 3  Ethanol  40.000000  ...  127:-2.146158  128:-2.488957
# 4  Ethanol  50.000000  ...  127:-2.931265  128:-4.088756
#
# [5 rows x 130 columns]

# %%
batch_1['Gas_Name'].value_counts()
# Out:
# Ethylene        98
# Ethanol         90
# Ammonia         83
# Toluene         74
# Acetone         70
# Acetaldehyde    30
# Name: Gas_Name, dtype: int64

# %%
for j in list(batch_1.iloc[:,2:].columns):
    d=[]
    for i in list(batch_1[j].values):
        d.append(i.split(':')[1])
    batch_1[j]=d
    
    
print(batch_1.shape)
batch_1.head()
# Out:
# (445, 130)
#   Gas_Name          0             1  ...        126        127        128
# 0  Ethanol  10.000000  15596.162100  ...  -0.545079  -0.902241  -2.654529
# 1  Ethanol  20.000000  26402.070400  ...  -0.889333  -1.323505  -1.749225
# 2  Ethanol  30.000000  42103.582000  ...  -1.334558  -1.993659  -2.348370
# 3  Ethanol  40.000000  42825.988300  ...  -1.432205  -2.146158  -2.488957
# 4  Ethanol  50.000000  58151.175700  ...  -1.930107  -2.931265  -4.088756
#
# [5 rows x 130 columns]

# %%
batch_1.set_index('Gas_Name',inplace=True)
print(batch_1.shape)
batch_1.head()
# Out:
# (445, 129)
#                   0             1         2  ...        126        127        128
# Gas_Name                                     ...
# Ethanol   10.000000  15596.162100  1.868245  ...  -0.545079  -0.902241  -2.654529
# Ethanol   20.000000  26402.070400  2.532401  ...  -0.889333  -1.323505  -1.749225
# Ethanol   30.000000  42103.582000  3.454189  ...  -1.334558  -1.993659  -2.348370
# Ethanol   40.000000  42825.988300  3.451192  ...  -1.432205  -2.146158  -2.488957
# Ethanol   50.000000  58151.175700  4.194839  ...  -1.930107  -2.931265  -4.088756
#
# [5 rows x 129 columns]

# %%
batch_1.reset_index(inplace=True)

# %%
df = batch_1
cols = df.columns.tolist()
#col = cols[-1:] + cols[:-1]
col = cols[1:] + cols[:1]
df = df[col]
df.to_csv('batch1.csv',index=False)

# %% [markdown]
# #Explore batch2.dat file

# %%
batch = pd.read_csv('batch2.dat' , delimiter=' ' , header = None)
print(batch.shape)
batch.head()
# Out:
# (1244, 130)
#            0               1           2    ...            127            128 129
# 0  1;10.000000  1:21749.563500  2:2.627488  ...  127:-1.218104  128:-1.605704 NaN
# 1  1;20.000000  1:44240.502900  2:4.734847  ...  127:-1.949090  128:-2.349524 NaN
# 2  1;30.000000  1:68772.517500  2:7.185827  ...  127:-2.711049  128:-4.501320 NaN
# 3  1;40.000000  1:68632.830100  2:6.923039  ...  127:-3.145986  128:-4.389490 NaN
# 4  1;50.000000  1:76428.971700  2:7.898322  ...  127:-3.776622  128:-4.187686 NaN
#
# [5 rows x 130 columns]

# %%
k  = batch
d=[]
for i in list(k[0].values):
    d.append(i.split(';')[0])
set(d)
# Out:
# {'1', '2', '3', '4', '5', '6'}

# %%
d=[]
h=[]
for i in list(batch[0].values):
    d.append(i.split(';')[1])
    h.append(i.split(';')[0])
batch[0]=d
batch.insert(0, "Gases",h, True) 
print(batch.shape)
batch.head()
# Out:
# (1244, 131)
#   Gases          0               1  ...            127            128 129
# 0     1  10.000000  1:21749.563500  ...  127:-1.218104  128:-1.605704 NaN
# 1     1  20.000000  1:44240.502900  ...  127:-1.949090  128:-2.349524 NaN
# 2     1  30.000000  1:68772.517500  ...  127:-2.711049  128:-4.501320 NaN
# 3     1  40.000000  1:68632.830100  ...  127:-3.145986  128:-4.389490 NaN
# 4     1  50.000000  1:76428.971700  ...  127:-3.776622  128:-4.187686 NaN
#
# [5 rows x 131 columns]

# %%
liss = []
for i in list(batch.columns):
    liss.append(str(i))
batch.columns = liss

# %%
#batch.info(include='all')
batch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1244 entries, 0 to 1243
# Columns: 131 entries, Gases to 129
# dtypes: float64(1), object(130)
# memory usage: 1.2+ MB

# %%
batch['129'].value_counts()
# Out:
# Series([], Name: 129, dtype: int64)

# %%
batch.drop(['129'] , inplace=True , axis = 1)

# %%
print(batch.shape)
batch.head()
# Out:
# (1244, 130)
#   Gases          0               1  ...            126            127            128
# 0     1  10.000000  1:21749.563500  ...  126:-0.760981  127:-1.218104  128:-1.605704
# 1     1  20.000000  1:44240.502900  ...  126:-1.277148  127:-1.949090  128:-2.349524
# 2     1  30.000000  1:68772.517500  ...  126:-1.734698  127:-2.711049  128:-4.501320
# 3     1  40.000000  1:68632.830100  ...  126:-2.054283  127:-3.145986  128:-4.389490
# 4     1  50.000000  1:76428.971700  ...  126:-2.435697  127:-3.776622  128:-4.187686
#
# [5 rows x 130 columns]

# %%
batch['Gases'].value_counts()
# Out:
# 5    532
# 2    334
# 1    164
# 4    109
# 3    100
# 6      5
# Name: Gases, dtype: int64

# %%
list(batch['Gases'].values)[:5]
# Out:
# ['1', '1', '1', '1', '1']

# %%
batch['Gases'] = batch['Gases'].astype('int64')


#pd.DataFrame(batch_1.iloc[:,0]).info()
pd.DataFrame(batch['Gases']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1244 entries, 0 to 1243
# Data columns (total 1 columns):
# Gases    1244 non-null int64
# dtypes: int64(1)
# memory usage: 9.8 KB

# %%
#  Ethanol, Ethylene, Ammonia, Acetaldehyde, Acetone, Toluene 
d=[]
for i in list(batch['Gases'].values):
    if(i==1):
        d.append('Ethanol')
    elif(i==2):
        d.append('Ethylene')
    elif(i==3):
        d.append('Ammonia')
    elif(i==4):
        d.append('Acetaldehyde')
    elif(i==5):
        d.append('Acetone')
    else:
        d.append('Toluene')
        
set(d)
# Out:
# {'Acetaldehyde', 'Acetone', 'Ammonia', 'Ethanol', 'Ethylene', 'Toluene'}

# %%
batch.insert(0, 'Gas_Name',d, True) 
batch.drop(['Gases'] , inplace=True , axis = 1)
print(batch.shape)
batch.head()
# Out:
# (1244, 130)
#   Gas_Name          0  ...            127            128
# 0  Ethanol  10.000000  ...  127:-1.218104  128:-1.605704
# 1  Ethanol  20.000000  ...  127:-1.949090  128:-2.349524
# 2  Ethanol  30.000000  ...  127:-2.711049  128:-4.501320
# 3  Ethanol  40.000000  ...  127:-3.145986  128:-4.389490
# 4  Ethanol  50.000000  ...  127:-3.776622  128:-4.187686
#
# [5 rows x 130 columns]

# %%
batch['Gas_Name'].value_counts()
# Out:
# Acetone         532
# Ethylene        334
# Ethanol         164
# Acetaldehyde    109
# Ammonia         100
# Toluene           5
# Name: Gas_Name, dtype: int64

# %%
for j in list(batch.iloc[:,2:].columns):
    d=[]
    for i in list(batch[j].values):
        d.append(i.split(':')[1])
    batch[j]=d
    
    
print(batch.shape)
batch.head()
# Out:
# (1244, 130)
#   Gas_Name          0             1  ...        126        127        128
# 0  Ethanol  10.000000  21749.563500  ...  -0.760981  -1.218104  -1.605704
# 1  Ethanol  20.000000  44240.502900  ...  -1.277148  -1.949090  -2.349524
# 2  Ethanol  30.000000  68772.517500  ...  -1.734698  -2.711049  -4.501320
# 3  Ethanol  40.000000  68632.830100  ...  -2.054283  -3.145986  -4.389490
# 4  Ethanol  50.000000  76428.971700  ...  -2.435697  -3.776622  -4.187686
#
# [5 rows x 130 columns]

# %%
batch.set_index('Gas_Name',inplace=True)
print(batch.shape)
batch.head()
# Out:
# (1244, 129)
#                   0             1         2  ...        126        127        128
# Gas_Name                                     ...
# Ethanol   10.000000  21749.563500  2.627488  ...  -0.760981  -1.218104  -1.605704
# Ethanol   20.000000  44240.502900  4.734847  ...  -1.277148  -1.949090  -2.349524
# Ethanol   30.000000  68772.517500  7.185827  ...  -1.734698  -2.711049  -4.501320
# Ethanol   40.000000  68632.830100  6.923039  ...  -2.054283  -3.145986  -4.389490
# Ethanol   50.000000  76428.971700  7.898322  ...  -2.435697  -3.776622  -4.187686
#
# [5 rows x 129 columns]

# %%
batch.reset_index(inplace=True)
df = batch
cols = df.columns.tolist()
#col = cols[-1:] + cols[:-1]
col = cols[1:] + cols[:1]
df = df[col]
df.to_csv('batch2.csv',index=False)

# %% [markdown]
# #Explore ALL batch3.dat to batch10.dat files

# %%
l= ['batch10.dat','batch9.dat','batch8.dat' ,'batch7.dat' ,'batch6.dat' ,'batch5.dat' ,'batch4.dat'  ,'batch3.dat']           
for file in l[::-1]:
    batch = pd.read_csv(file, delimiter=' ' , header = None)
    d=[]
    h=[]
    for i in list(batch[0].values):
        d.append(i.split(';')[1])
        h.append(i.split(';')[0])
    batch[0]=d
    batch.insert(0, "Gases",h, True)
    liss = []
    for i in list(batch.columns):
        liss.append(str(i))
    batch.columns = liss
    batch.drop(['129'] , inplace=True , axis = 1)
    batch['Gases'] = batch['Gases'].astype('int64')

    d1=[]
    for i in list(batch['Gases'].values):
        if(i==1):
            d1.append('Ethanol')
        elif(i==2):
            d1.append('Ethylene')
        elif(i==3):
            d1.append('Ammonia')
        elif(i==4):
            d1.append('Acetaldehyde')
        elif(i==5):
            d1.append('Acetone')
        else:
            d1.append('Toluene')
    batch.insert(0, 'Gas_Name',d1, True) 
    batch.drop(['Gases'] , inplace=True , axis = 1)
    for j in list(batch.iloc[:,2:].columns):
        d=[]
        for i in list(batch[j].values):
            d.append(i.split(':')[1])
        batch[j]=d
    batch.set_index('Gas_Name',inplace=True)
    batch.reset_index(inplace=True)
    df = batch
    cols = df.columns.tolist()
    #col = cols[-1:] + cols[:-1]
    col = cols[1:] + cols[:1]
    df = df[col]
    df.to_csv(file.split('.')[0]+'.csv',index=False)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---

# %%
import numpy as np 
s = pd.DataFrame([49,48,47,46,45, 1, 2, 3, 4, 5] )
s['1'] = 
s
import random
p=[]
for i in range(10):
    p.append(random.randint(0,100))
s['4'] = p
s.iloc[: , 2:4]
