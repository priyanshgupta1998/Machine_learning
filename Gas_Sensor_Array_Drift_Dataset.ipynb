# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshgupta1998/Machine_learning/blob/master/Gas_Sensor_Array_Drift_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #

# %% [markdown]
# https://archive.ics.uci.edu/ml/datasets/gas+sensor+array+drift+dataset
#
# https://archive.ics.uci.edu/ml/datasets/Gas+Sensor+Array+Drift+Dataset+at+Different+Concentrations
#
# https://www.kaggle.com/jihyeseo/regression-no-missing-val-data-delim-whitespace

# %% [markdown]
# #Data Pre-Processing
#
# `There are 129 features in the dataset. The very first feature has the gas class and concentration concatenated using a semi-colon.`
# `Other 128 features have the feature number conactenated with actual data using a colon.`
# `Data pre-processing is required to address 1 and 2. First feature was split into two features GAS and CONC (concentration). For all other features the feature number was discarded and an appropriate column name was given. For example S11I_001 column is the increasing current reading for sensor 11 when alpha = 0.001.`
#
# `All ten batches were combined into a single data set with an additional column 'BATCH' denoting the batch to which the observation belongs. Final clean data set contains 131 variables (128 current reading features + gas + concentration + batch) with 13910 rows.`
#
# # Current Task
# `Currently doing data exploration and dimensionality reduction using PCA.`

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00224/Dataset.zip
# Out:
# --2019-05-29 11:10:00--  https://archive.ics.uci.edu/ml/machine-learning-databases/00224/Dataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9989262 (9.5M) [application/x-httpd-php]
# Saving to: ‘Dataset.zip’
#
# Dataset.zip         100%[===================>]   9.53M  19.5MB/s    in 0.5s
#
# 2019-05-29 11:10:05 (19.5 MB/s) - ‘Dataset.zip’ saved [9989262/9989262]

# %%
# !unzip Dataset.zip
# Out:
# Archive:  Dataset.zip
#    creating: Dataset/
#   inflating: Dataset/batch1.dat
#   inflating: Dataset/batch10.dat
#   inflating: Dataset/batch2.dat
#   inflating: Dataset/batch3.dat
#   inflating: Dataset/batch4.dat
#   inflating: Dataset/batch5.dat
#   inflating: Dataset/batch6.dat
#   inflating: Dataset/batch7.dat
#   inflating: Dataset/batch8.dat
#   inflating: Dataset/batch9.dat

# %%
import pandas as pd

# %%
batch_1 = pd.read_csv('Dataset/batch1.dat' , delimiter=' ',)
print(batch_1.shape)
batch_1.head()
# Out:
# (444, 129)
#    1  1:15596.162100  2:1.868245  ...  126:-0.545079  127:-0.902241  128:-2.654529
# 0  1  1:26402.070400  2:2.532401  ...  126:-0.889333  127:-1.323505  128:-1.749225
# 1  1  1:42103.582000  2:3.454189  ...  126:-1.334558  127:-1.993659  128:-2.348370
# 2  1  1:42825.988300  2:3.451192  ...  126:-1.432205  127:-2.146158  128:-2.488957
# 3  1  1:58151.175700  2:4.194839  ...  126:-1.930107  127:-2.931265  128:-4.088756
# 4  1  1:79872.130800  2:5.553595  ...  126:-2.688513  127:-4.173558  128:-4.808914
#
# [5 rows x 129 columns]

# %%
batch_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Columns: 129 entries, 1 to 128:-2.654529
# dtypes: int64(1), object(128)
# memory usage: 447.5+ KB

# %%
batch_2 = pd.read_csv('Dataset/batch2.dat' , delimiter=' ',)
print(batch_2.shape)
batch_2.head()
# Out:
# (1243, 129)
#    1   1:21749.563500  2:2.627488  ...  126:-0.760981  127:-1.218104  128:-1.605704
# 0  1   1:44240.502900  2:4.734847  ...  126:-1.277148  127:-1.949090  128:-2.349524
# 1  1   1:68772.517500  2:7.185827  ...  126:-1.734698  127:-2.711049  128:-4.501320
# 2  1   1:68632.830100  2:6.923039  ...  126:-2.054283  127:-3.145986  128:-4.389490
# 3  1   1:76428.971700  2:7.898322  ...  126:-2.435697  127:-3.776622  128:-4.187686
# 4  1  1:100000.392600  2:9.904068  ...  126:-3.270087  127:-5.251693  128:-5.596326
#
# [5 rows x 129 columns]

# %%
batch_2.info('All')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1243 entries, 0 to 1242
# Data columns (total 129 columns):
# 1                  int64
# 1:21749.563500     object
# 2:2.627488         object
# 3:3.507524         object
# 4:4.110899         object
# 5:5.015697         object
# 6:-3.474738        object
# 7:-4.569693        object
# 8:-13.448491       object
# 9:21138.044000     object
# 10:2.713281        object
# 11:3.612213        object
# 12:4.281570        object
# 13:5.026986        object
# 14:-3.252127       object
# 15:-3.995530       object
# 16:-11.599578      object
# 17:2601.824900     object
# 18:2.085748        object
# 19:0.723314        object
# 20:1.161237        object
# 21:1.587376        object
# 22:-0.516412       object
# 23:-0.824780       object
# 24:-1.112882       object
# 25:2602.686500     object
# 26:2.074977        object
# 27:0.723795        object
# 28:1.216273        object
# 29:2.594866        object
# 30:-0.520201       object
# 31:-0.855015       object
# 32:-2.791243       object
# 33:1218.549700     object
# 34:2.092544        object
# 35:0.395898        object
# 36:0.863491        object
# 37:1.145358        object
# 38:-0.252613       object
# 39:-0.408573       object
# 40:-1.150768       object
# 41:1407.787600     object
# 42:2.104463        object
# 43:0.446390        object
# 44:0.912604        object
# 45:1.218736        object
# 46:-0.292121       object
# 47:-0.484320       object
# 48:-1.309839       object
# 49:3321.709000     object
# 50:2.414840        object
# 51:1.030390        object
# 52:1.959228        object
# 53:2.460395        object
# 54:-0.709820       object
# 55:-1.184975       object
# 56:-1.387163       object
# 57:3501.094500     object
# 58:2.406442        object
# 59:1.068712        object
# 60:1.984295        object
# 61:2.354542        object
# 62:-0.744714       object
# 63:-1.227309       object
# 64:-3.471172       object
# 65:20407.455100    object
# 66:2.849163        object
# 67:3.246597        object
# 68:3.794115        object
# 69:4.485362        object
# 70:-2.902923       object
# 71:-3.666017       object
# 72:-9.839388       object
# 73:24773.999000    object
# 74:2.947995        object
# 75:3.898243        object
# 76:4.526107        object
# 77:5.474420        object
# 78:-3.691419       object
# 79:-4.553467       object
# 80:-12.050995      object
# 81:3173.884000     object
# 82:2.201685        object
# 83:0.871304        object
# 84:1.315971        object
# 85:1.629180        object
# 86:-0.604284       object
# 87:-0.911772       object
# 88:-2.622255       object
# 89:2369.014400     object
# 90:2.202927        object
# 91:0.675708        object
# 92:1.110452        object
# 93:1.405526        object
# 94:-0.477064       object
# 95:-0.760527       object
# 96:-0.986015       object
# 97:1636.158800     object
# 98:2.163980        object
# 99:0.535716        object
# 100:1.052986       object
# 101:1.820696       object
# 102:-0.332063      object
# 103:-0.530287      object
# 104:-1.500841      object
# 105:1657.308000    object
# 106:2.161844       object
# 107:0.553001       object
# 108:1.157846       object
# 109:1.508133       object
# 110:-0.334765      object
# 111:-0.535050      object
# 112:-1.521051      object
# 113:3955.409400    object
# 114:2.519815       object
# 115:1.205705       object
# 116:2.145977       object
# 117:2.597082       object
# 118:-0.838715      object
# 119:-1.352179      object
# 120:-3.798715      object
# 121:3573.044700    object
# 122:2.582159       object
# 123:1.120364       object
# 124:2.113358       object
# 125:2.388007       object
# 126:-0.760981      object
# 127:-1.218104      object
# 128:-1.605704      object
# dtypes: int64(1), object(128)
# memory usage: 1.2+ MB
# None
